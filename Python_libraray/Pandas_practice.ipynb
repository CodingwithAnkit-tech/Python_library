# %%
# import essential libraries
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Practice/blinkit_cleaned%20(1)")

# %%
df
# Out:
#       Unnamed: 0 Item Fat Content Item Identifier              Item Type  \
# 0              0          Regular           FDX32  Fruits and Vegetables
# 1              1          Low Fat           NCB42     Health and Hygiene
# 2              2          Regular           FDR28           Frozen Foods
# 3              3          Regular           FDL50                 Canned
# 4              4          Low Fat           DRI25            Soft Drinks
# ...          ...              ...             ...                    ...
# 8518        8518          Low Fat           NCT53     Health and Hygiene
# 8519        8519          Low Fat           FDN09            Snack Foods
# 8520        8520          Low Fat           DRE13            Soft Drinks
# 8521        8521          Regular           FDT50                  Dairy
# 8522        8522          Regular           FDM58            Snack Foods
#
#       Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 8523 non-null   int64
#  1   Item Fat Content           8523 non-null   object
#  2   Item Identifier            8523 non-null   object
#  3   Item Type                  8523 non-null   object
#  4   Outlet Establishment Year  8523 non-null   int64
#  5   Outlet Identifier          8523 non-null   object
#  6   Outlet Location Type       8523 non-null   object
#  7   Outlet Size                8523 non-null   object
#  8   Outlet Type                8523 non-null   object
#  9   Item Visibility            8523 non-null   float64
#  10  Item Weight                8523 non-null   float64
#  11  Sales                      8523 non-null   float64
#  12  Rating                     8523 non-null   float64
# ...

# %%
df["Outlet Identifier"].value_counts()
# Out:
# Outlet Identifier
# OUT027    935
# OUT013    932
# OUT035    930
# OUT049    930
# OUT046    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Item Fat Content', 'Item Identifier', 'Item Type',
#        'Outlet Establishment Year', 'Outlet Identifier',
#        'Outlet Location Type', 'Outlet Size', 'Outlet Type', 'Item Visibility',
#        'Item Weight', 'Sales', 'Rating'],
#       dtype='object')

# %%
df.sample()
# Out:
#       Unnamed: 0 Item Fat Content Item Identifier Item Type  \
# 5953        5953          Regular           FDP51      Meat
#
#       Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 5953                       2022            OUT018               Tier 3
#
#      Outlet Size        Outlet Type  Item Visibility  Item Weight     Sales  \
# 5953      Medium  Supermarket Type2         0.085622        13.85  119.4124
#
#       Rating
# 5953     4.0

# %%
df.sample(5)
# Out:
#       Unnamed: 0 Item Fat Content Item Identifier           Item Type  \
# 6958        6958          Low Fat           NCR30           Household
# 3469        3469          Low Fat           NCZ41  Health and Hygiene
# 5922        5922          Low Fat           NCM31              Others
# 3249        3249          Low Fat           NCP06           Household
# 4              4          Low Fat           DRI25         Soft Drinks
#
#       Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 6958                       2015            OUT045               Tier 2
# 3469                       2020            OUT017               Tier 2
# 5922                       2016            OUT046               Tier 1
# 3249                       2018            OUT027               Tier 3
# 4                          2015            OUT045               Tier 2
#
#      Outlet Size        Outlet Type  Item Visibility  Item Weight     Sales  \
# ...

# %%
df.sort_values("Item Type")
# Out:
#       Unnamed: 0 Item Fat Content Item Identifier      Item Type  \
# 7988        7988          Low Fat           FDU36   Baking Goods
# 5929        5929          Regular           FDX36   Baking Goods
# 7171        7171          Regular           FDS24   Baking Goods
# 4975        4975          Low Fat           FDX23   Baking Goods
# 4976        4976          Low Fat           FDF12   Baking Goods
# ...          ...              ...             ...            ...
# 3417        3417          Regular           FDE23  Starchy Foods
# 4484        4484          Regular           FDB23  Starchy Foods
# 735          735          Low Fat           FDB11  Starchy Foods
# 7972        7972          Low Fat           FDE47  Starchy Foods
# 3110        3110          Low Fat           FDC23  Starchy Foods
#
#       Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 7988                       2022            OUT018               Tier 3
# ...

# %%
df.loc[22:50]
# Out:
#     Unnamed: 0 Item Fat Content Item Identifier              Item Type  \
# 22          22          Low Fat           FDJ41           Frozen Foods
# 23          23          Low Fat           DRI51                  Dairy
# 24          24          Regular           FDC40                  Dairy
# 25          25          Low Fat           FDB53           Frozen Foods
# 26          26          Low Fat           FDA16           Frozen Foods
# 27          27          Regular           FDO19  Fruits and Vegetables
# 28          28          Low Fat           FDO04           Frozen Foods
# 29          29          Regular           FDL25              Breakfast
# 30          30          Low Fat           NCJ30              Household
# 31          31          Low Fat           NCQ41     Health and Hygiene
# 32          32          Low Fat           DRJ35            Hard Drinks
# 33          33          Low Fat           NCE31              Household
# ...

# %%
df.loc[2452]
# Out:
# Unnamed: 0                            2452
# Item Fat Content                   Low Fat
# Item Identifier                      FDK09
# Item Type                      Snack Foods
# Outlet Establishment Year             2011
# Outlet Identifier                   OUT010
# Outlet Location Type                Tier 3
# Outlet Size                           High
# Outlet Type                  Grocery Store
# Item Visibility                   0.153593
# Item Weight                           15.2
# Sales                             228.0352
# Rating                                 4.2
# Name: 2452, dtype: object

# %%
df.loc[55:60]
# Out:
#     Unnamed: 0 Item Fat Content Item Identifier              Item Type  \
# 55          55          Low Fat           FDP04           Frozen Foods
# 56          56          Low Fat           FDD05           Frozen Foods
# 57          57          Low Fat           FDV07  Fruits and Vegetables
# 58          58          Low Fat           FDT20  Fruits and Vegetables
# 59          59          Low Fat           FDC44  Fruits and Vegetables
# 60          60          Low Fat           DRM59            Hard Drinks
#
#     Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 55                       2012            OUT049               Tier 1
# 56                       2012            OUT049               Tier 1
# 57                       2012            OUT049               Tier 1
# 58                       2012            OUT049               Tier 1
# 59                       2012            OUT049               Tier 1
# ...

# %%
len(df)
# Out:
# 8523

# %%
df.shape
# Out:
# (8523, 13)
